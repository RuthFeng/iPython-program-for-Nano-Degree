# %% [markdown]
# ## 探索电影数据集
#
# 在这个项目中，你将尝试使用所学的知识，使用 `NumPy`、`Pandas`、`matplotlib`、`seaborn` 库中的函数，来对电影数据集进行探索。
#
# 下载数据集：
# [TMDb电影数据](https://s3.cn-north-1.amazonaws.com.cn/static-documents/nd101/explore+dataset/tmdb-movies.csv)

# %% [markdown]
# 数据集各列名称的含义：
# <table>
# <thead><tr><th>列名称</th><th>id</th><th>imdb_id</th><th>popularity</th><th>budget</th><th>revenue</th><th>original_title</th><th>cast</th><th>homepage</th><th>director</th><th>tagline</th><th>keywords</th><th>overview</th><th>runtime</th><th>genres</th><th>production_companies</th><th>release_date</th><th>vote_count</th><th>vote_average</th><th>release_year</th><th>budget_adj</th><th>revenue_adj</th></tr></thead><tbody>
#  <tr><td>含义</td><td>编号</td><td>IMDB 编号</td><td>知名度</td><td>预算</td><td>票房</td><td>名称</td><td>主演</td><td>网站</td><td>导演</td><td>宣传词</td><td>关键词</td><td>简介</td><td>时常</td><td>类别</td><td>发行公司</td><td>发行日期</td><td>投票总数</td><td>投票均值</td><td>发行年份</td><td>预算（调整后）</td><td>票房（调整后）</td></tr>
# </tbody></table>

# %% [markdown]
# **请注意，你需要提交该报告导出的 `.html`、`.ipynb` 以及 `.py` 文件。**

# %% [markdown]
# ---
#
# ---
#
# ## 第一节 数据的导入与处理
#
# 在这一部分，你需要编写代码，使用 Pandas 读取数据，并进行预处理。

# %% [markdown]
# **任务1.1：** 导入库以及数据
#
# 1. 载入需要的库 `NumPy`、`Pandas`、`matplotlib`、`seaborn`。
# 2. 利用 `Pandas` 库，读取 `tmdb-movies.csv` 中的数据，保存为 `movie_data`。
#
# 提示：记得使用 notebook 中的魔法指令 `%matplotlib inline`，否则会导致你接下来无法打印出图像。

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
% matplotlib inline

movie_data=pd.read_csv('tmdb-movies.csv')

# %% [markdown]
# ---
#
# **任务1.2: ** 了解数据
#
# 你会接触到各种各样的数据表，因此在读取之后，我们有必要通过一些简单的方法，来了解我们数据表是什么样子的。
#
# 1. 获取数据表的行列，并打印。
# 2. 使用 `.head()`、`.tail()`、`.sample()` 方法，观察、了解数据表的情况。
# 3. 使用 `.dtypes` 属性，来查看各列数据的数据类型。
# 4. 使用 `isnull()` 配合 `.any()` 等方法，来查看各列是否存在空值。
# 5. 使用 `.describe()` 方法，看看数据表中数值型的数据是怎么分布的。

# %%
print('The row index in movie_data is:', movie_data.index)
print()
print('The column index in movie_data is:', movie_data.columns)
# Out:
# The row index in movie_data is: RangeIndex(start=0, stop=10866, step=1)
#
# The column index in movie_data is: Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)
movie_data.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
movie_data.tail()
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10861     21  tt0060371    0.080598       0        0
# 10862  20379  tt0060472    0.065543       0        0
# 10863  39768  tt0060161    0.065141       0        0
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10861        The Endless Summer
# 10862                Grand Prix
# 10863       Beregis Avtomobilya
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...      NaN
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...      NaN
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      NaN
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
# ...

# %%
movie_data.sample()
# Out:
#          id    imdb_id  popularity  budget  revenue   original_title  \
# 9706  26827  tt0094321    0.135106       0  7305209  Who's That Girl
#
#                                                    cast homepage     director  \
# 9706  Madonna|Griffin Dunne|Bibi Besch|John McMartin...      NaN  James Foley
#
#                                                 tagline  \
# 9706  A funny thing happened on the way to the bus s...
#
#                                          keywords  \
# 9706  new york|falsely accused person|cult comedy
#
#                                                overview  runtime  \
# 9706  An uptight New York tax lawyer gets his life t...       92
#
#                              genres  \
# 9706  Comedy|Thriller|Music|Romance
#
#                                 production_companies release_date  vote_count  \
# 9706  Warner Bros. Pictures|The Guber-Peters Company       8/7/87          18
#
#       vote_average  release_year  budget_adj   revenue_adj
# ...

# %%
print('movie_data.dtypes:\n',movie_data.dtypes)
print('\n movie_data.isnull().any():\n',movie_data.isnull().any())
print('\n movie_data.describe():\n')
movie_data.describe()
# Out:
# movie_data.dtypes:
#  id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object
#
#  movie_data.isnull().any():
#  id                      False
# imdb_id                  True
# popularity              False
# budget                  False
# revenue                 False
# original_title          False
# ...

# %% [markdown]
# 可以看到movie_data数据列没有空值.无需清洗.

# %% [markdown]
# ---
#
# **任务1.3: ** 清理数据
#
# 在真实的工作场景中，数据处理往往是最为费时费力的环节。但是幸运的是，我们提供给大家的 tmdb 数据集非常的「干净」，不需要大家做特别多的数据清洗以及处理工作。在这一步中，你的核心的工作主要是对数据表中的空值进行处理。你可以使用 `.fillna()` 来填补空值，当然也可以使用 `.dropna()` 来丢弃数据表中包含空值的某些行或者列。
#
# 任务：使用适当的方法来清理空值，并将得到的数据保存。

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10866 non-null int64
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# ...

# %% [markdown]
# 可以看到int64和float64类型的数据列并没有空值.其余字段有空值,除了imdb_id为空和重复可能影响到数据的真实性,因此先删除imdb_id列重复和空值的行.
#
# tips:
# 现在分享一些检查空值的技巧:这个数据的缺失包括字符型数据的缺失和数值型数据的缺失, 你应该分开处理, 首先你可以快速用
# movie_data.info()
# 快速检查数据的类型和缺失情况
# 字符型的缺失很多时候可以用'Unknown'来填充, (这个数据集的缺失/异常都是字符型). 如果缺失很少, 我们可以进行移除
# 数值型的缺失/异常有几种处理的方式(这个数据集的收入/预算很多0值):
# 删除: pandas.DataFrame.dropna
# 填充: pandas.DataFrame.fillna
# 根据需要, 一般会用统计数据, 比如均值, 中位数填充
# 插值: pandas.DataFrame.interpolate
# 根据无效值的前后值, 进行估计并填充, 适合连续有序的数据. 比如[1, 2, NaN, 4] 插值后就是[1, 2, 3, 4]
# 替换: pandas.DataFrame.replace
# 参考: https://pandas.pydata.org/pandas-docs/stable/missing_data.html

# %%
def drop_na(df,colname,keywords):
    df[colname]=df[colname].fillna(keywords)
    df=df.drop(df[df[colname]==keywords].index.tolist())
    return df

movie_data=drop_na(movie_data,'imdb_id','tobedroped')

# %%
movie_data[movie_data.duplicated(subset='imdb_id',keep=False)]
# Out:
#          id    imdb_id  popularity    budget  revenue original_title  \
# 2089  42194  tt0411951     0.59643  30000000   967000         TEKKEN
# 2090  42194  tt0411951     0.59643  30000000   967000         TEKKEN
#
#                                                    cast homepage  \
# 2089  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline  \
# 2089  Dwight H. Little  Survival is no game
# 2090  Dwight H. Little  Survival is no game
#
#                                                keywords  \
# 2089  martial arts|dystopia|based on video game|mart...
# 2090  martial arts|dystopia|based on video game|mart...
#
#                                                overview  runtime  \
# 2089  In the year of 2039, after World Wars destroy ...       92
# 2090  In the year of 2039, after World Wars destroy ...       92
#
# ...

# %%
movie_data=movie_data.drop(movie_data[movie_data.duplicated(subset='imdb_id', keep='first')].index.tolist())

# %%
movie_data[movie_data.duplicated(subset='imdb_id',keep=False)]
# Out:
# Empty DataFrame
# Columns: [id, imdb_id, popularity, budget, revenue, original_title, cast, homepage, director, tagline, keywords, overview, runtime, genres, production_companies, release_date, vote_count, vote_average, release_year, budget_adj, revenue_adj]
# Index: []

# %% [markdown]
# 第三节分析涉及'revenue_adj','budget_adj'两个数值类型字段,按照常识来说,预算这一块不可能为0,收入这一块倒是有可能为0.从第一节可以看到'budget_adj'有0的记录,因此删除'budget_adj'为0的行.

# %%
movie_data[movie_data['budget_adj']==0.0]
# Out:
#            id    imdb_id  popularity  budget    revenue  \
# 30     280996  tt3168230    3.927333       0   29355203
# 36     339527  tt1291570    3.358321       0   22354572
# 72     284289  tt2911668    2.272044       0      45895
# 74     347096  tt3478232    2.165433       0          0
# 75     308369  tt2582496    2.141506       0          0
# 88     301875  tt3289728    1.959765       0    2000000
# 92     370687  tt3608646    1.876037       0          0
# 95     258509  tt2974918    1.841779       0  233755553
# 100    326359  tt4007502    1.724712       0          0
# 101    254302  tt0462335    1.661789       0          0
# 103    292040  tt3321300    1.646664       0          0
# 116    297291  tt3086386    1.380320       0          0
# 119     86828  tt1727770    1.360827       0    5189646
# 122    277355  tt1945084    1.342839       0          0
# 125    223485  tt3205376    1.329702       0     229094
# 128    309245  tt2872462    1.293140       0    2500431
# ...

# %%
movie_data=drop_na(movie_data,'budget_adj',0.0)

# %%
movie_data[movie_data['budget_adj']==0.0]
# Out:
# Empty DataFrame
# Columns: [id, imdb_id, popularity, budget, revenue, original_title, cast, homepage, director, tagline, keywords, overview, runtime, genres, production_companies, release_date, vote_count, vote_average, release_year, budget_adj, revenue_adj]
# Index: []

# %%
import missingno
missingno.matrix(movie_data)

# %% [markdown]
# ---
#
# ---
#
# ## 第二节 根据指定要求读取数据
#
#
# 相比 Excel 等数据分析软件，Pandas 的一大特长在于，能够轻松地基于复杂的逻辑选择合适的数据。因此，如何根据指定的要求，从数据表当获取适当的数据，是使用 Pandas 中非常重要的技能，也是本节重点考察大家的内容。

# %% [markdown]
# ---
#
# **任务2.1: ** 简单读取
#
# 1. 读取数据表中名为 `id`、`popularity`、`budget`、`runtime`、`vote_average` 列的数据。
# 2. 读取数据表中前1～20行以及48、49行的数据。
# 3. 读取数据表中第50～60行的 `popularity` 那一列的数据。
#
# 要求：每一个语句只能用一行代码实现。

# %%
#https://blog.csdn.net/Guo_ya_nan/article/details/81015914
filter_data1=pd.DataFrame(movie_data[['id','popularity','budget','runtime','vote_average']])
filter_data2=pd.DataFrame(movie_data.loc[list(range(20))+list([47,48])])
filter_data3=pd.DataFrame(movie_data.loc[49:59,'popularity'])
#3 读取数据表中第50～60行这个题目是要求包含60吧?.loc在这里没有包含尾部

# %%
filter_data3
# Out:
#     popularity
# 49    2.885126
# 50    2.883233
# 51    2.814802
# 52    2.798017
# 53    2.793297
# 54    2.614499
# 55    2.584264
# 56    2.578919
# 57    2.575711
# 58    2.557859
# 59    2.550747

# %% [markdown]
# ---
#
# **任务2.2: **逻辑读取（Logical Indexing）
#
# 1. 读取数据表中 **`popularity` 大于5** 的所有数据。
# 2. 读取数据表中 **`popularity` 大于5** 的所有数据且**发行年份在1996年之后**的所有数据。
#
# 提示：Pandas 中的逻辑运算符如 `&`、`|`，分别代表`且`以及`或`。
#
# 要求：请使用 Logical Indexing实现。

# %%
large5_data=movie_data[movie_data['popularity']>5]
large5_data.describe()
large5_1996_data=movie_data[(movie_data['popularity']>5) & (movie_data['release_year']>1996) ]

# %% [markdown]
# ---
#
# **任务2.3: **分组读取
#
# 1. 对 `release_year` 进行分组，使用 [`.agg`](http://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.core.groupby.DataFrameGroupBy.agg.html) 获得 `revenue` 的均值。
# 2. 对 `director` 进行分组，使用 [`.agg`](http://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.core.groupby.DataFrameGroupBy.agg.html) 获得 `popularity` 的均值，从高到低排列。
#
# 要求：使用 `Groupby` 命令实现。

# %%
releaseyear_revenue_data=movie_data.groupby('release_year').agg({'revenue':['mean']}).xs('revenue', axis=1, drop_level=True).reset_index().rename({'mean':'revenue_mean'}, axis='columns')
releaseyear_revenue_data.head()
# Out:
#    release_year  revenue_mean
# 0          1960  1.433389e+07
# 1          1961  2.597848e+07
# 2          1962  1.473785e+07
# 3          1963  1.604790e+07
# 4          1964  2.987396e+07

# %% [markdown]
# #评论给出的方法很有效 https://www.jianshu.com/p/42f1d2909bb6
#
# pd.DataFrame(movie_data.groupby('release_year')['revenue'].mean()).rename({'revenue':'revenue_mean'},axis='columns').reset_index()

# %%
director_popu_data=movie_data.groupby('director').agg({'popularity':['mean']}).sort_values(by=[('popularity','mean')], ascending=False).xs('popularity', axis=1, drop_level=True).reset_index().rename({'mean':'popularity_mean'}, axis='columns')
director_popu_data.head()
#https://pandas.pydata.org/pandas-docs/stable/advanced.html#cross-section
#https://stackoverflow.com/questions/41221079/rename-multiindex-columns-in-pandas
#https://stackoverflow.com/questions/22233488/pandas-drop-a-level-from-a-multi-level-column-index
#s.reset_index(level='director', col_level=1, col_fill='species').reset_index(drop=True)
# Out:
#                       director  popularity_mean
# 0              Colin Trevorrow        16.696886
# 1      Joe Russo|Anthony Russo        12.971027
# 2  Chad Stahelski|David Leitch        11.422751
# 3      Don Hall|Chris Williams         8.691294
# 4                Morten Tyldum         8.110711

# %% [markdown]
# ---
#
# ---
#
# ## 第三节 绘图与可视化
#
# 接着你要尝试对你的数据进行图像的绘制以及可视化。这一节最重要的是，你能够选择合适的图像，对特定的可视化目标进行可视化。所谓可视化的目标，是你希望从可视化的过程中，观察到怎样的信息以及变化。例如，观察票房随着时间的变化、哪个导演最受欢迎等。
#
# <table>
# <thead><tr><th>可视化的目标</th><th>可以使用的图像</th></tr></thead><tbody>
#  <tr><td>表示某一属性数据的分布</td><td>饼图、直方图、散点图</td></tr>
#  <tr><td>表示某一属性数据随着某一个变量变化</td><td>条形图、折线图、热力图</td></tr>
#  <tr><td>比较多个属性的数据之间的关系</td><td>散点图、小提琴图、堆积条形图、堆积折线图</td></tr>
# </tbody></table>
#
# 在这个部分，你需要根据题目中问题，选择适当的可视化图像进行绘制，并进行相应的分析。对于选做题，他们具有一定的难度，你可以尝试挑战一下～

# %% [markdown]
# **任务3.1：**对 `popularity` 最高的20名电影绘制其 `popularity` 值。

# %%
#top_popularity=movie_data.sort_values(by=[('popularity')], ascending=False).iloc[:20,[movie_data.columns.get_loc('popularity'),movie_data.columns.get_loc('original_title')]]
#iloc不需要重置index,因为取真实排序行号,与index值无关.loc需要重置index,取index值.
top_popularity=movie_data.sort_values(by=[('popularity')], ascending=False).reset_index().loc[:19,['popularity','original_title']]

fig=plt.figure(figsize=(10,6))
label_list=top_popularity['original_title'].tolist()
x=range(len(label_list))
plt.bar(x, top_popularity.popularity.tolist(), width=0.4, alpha=0.8, color='blue') 

# 添加标题和坐标轴标签
plt.title('top 20 popularity movies')
plt.xlabel('original_title')
plt.ylabel('popularity',labelpad=4)
plt.xticks([index + 0.2 for index in x], label_list)

# 为了避免x轴日期刻度标签的重叠，设置x轴刻度自动展现，并且45度倾斜
fig.autofmt_xdate(rotation = 45)

# 显示图形
plt.show()

# %% [raw]
# ---
# **任务3.2：**分析电影净利润（票房-成本）随着年份变化的情况，并简单进行分析。

# %%
movie_data.loc[1:3]
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
#
#                  original_title  \
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
#
#                                                 cast  \
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
#
#                                             homepage          director  \
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
#
#                          tagline  \
# 1             What a Lovely Day.
# ...

# %%
movie_data['net_revenue_adj']=movie_data['revenue_adj']-movie_data['budget_adj']
net_revenue_data=movie_data.groupby('release_year').agg({'net_revenue_adj':['mean']}).xs('net_revenue_adj', axis=1, drop_level=True).reset_index().rename({'mean':'net_revenue_adj_mean'}, axis='columns')

#https://www.kesci.com/home/project/59f6f45ac5f3f511952c2bf8
# 设置图框的大小
fig=plt.figure(figsize=(10,6))
# 绘图
plt.plot(net_revenue_data.release_year, # x轴数据
         net_revenue_data.net_revenue_adj_mean, # y轴数据
         linestyle = '-', # 折线类型
         linewidth = 2, # 折线宽度
         color = 'steelblue', # 折线颜色
         marker = 'o', # 点的形状
         markersize = 6, # 点的大小
         markeredgecolor='black', # 点的边框色
         markerfacecolor='steelblue') # 点的填充色

# 添加标题和坐标轴标签
plt.title('mean_net_revenue_per year')
plt.xlabel('year')
plt.ylabel('net_revenue_mean')

# 剔除图框上边界和右边界的刻度
#plt.tick_params(top = 'off', right = 'off')


# 为了避免x轴日期刻度标签的重叠，设置x轴刻度自动展现，并且45度倾斜
fig.autofmt_xdate(rotation = 45)

# 显示图形
plt.show()

# %%
movie_data.iloc[1:3]
# Out:
#        id    imdb_id  popularity     budget    revenue      original_title  \
# 1   76341  tt1392190   28.419936  150000000  378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000  295238201           Insurgent
#
#                                                 cast  \
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
#
#                       tagline  \
# 1          What a Lovely Day.
# 2  One Choice Can Destroy You
#
#                                             keywords  \
# 1   future|chase|post-apocalyptic|dystopia|australia
# 2  based on novel|revolution|dystopia|sequel|dyst...
#
#                                             overview  runtime  \
# ...

# %% [markdown]
# 1960-1980年每部电影收益非常好,但是随着时代的发展,每部电影的净利润逐年下滑,2000年后的10年持续在低位维持.

# %% [markdown]
# 其他参考:
# plt.figure(figsize=(20, 6))
# movie_data['profit'] = movie_data['revenue'] - movie_data['budget']
# y_mean = movie_data.groupby('release_year')['profit'].mean()
# y_sem = movie_data.groupby('release_year')['profit'].sem()
# plt.errorbar(x=y_mean.index.astype(str), y=y_mean, yerr=y_sem)
# plt.xticks(rotation=90)
# plt.show()

# %% [markdown]
# ---
#
# **[选做]任务3.3：**选择最多产的10位导演（电影数量最多的），绘制他们排行前3的三部电影的票房情况，并简要进行分析。

# %%
#额,暂时不做
director_view=movie_data[['imdb_id','director']].groupby(['director']).count().reset_index()
director_view.columns=['director','movie_counts']
director_view=director_view.sort_values(by=[('movie_counts')], ascending=False).reset_index()
#director_view.head()
top_3_per_product=pd.DataFrame(columns=movie_data.columns.tolist())
for director in director_view['director'].loc[:9].tolist():
    top_3_per_product=top_3_per_product.append(pd.DataFrame(movie_data[movie_data['director']==director]).sort_values(by=[('revenue_adj')], ascending=False).reset_index().loc[:2])

top_3_per_product.head()
# Out:
# d:\Python\Anaconda2\envs\py37\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#      budget    budget_adj                                               cast  \
# 0   7000000  2.836275e+07  Roy Scheider|Robert Shaw|Richard Dreyfuss|Lorr...
# 1  10500000  2.372625e+07  Henry Thomas|Drew Barrymore|Robert MacNaughton...
# 2  63000000  9.509661e+07  Sam Neill|Laura Dern|Jeff Goldblum|Richard Att...
# 0  30000000  2.908194e+07  Owen Wilson|Rachel McAdams|Kurt Fuller|Mimi Ke...
# 1   4000000  1.439112e+07  Woody Allen|Diane Keaton|Tony Roberts|Carol Ka...
#
#            director                                    genres  \
# 0  Steven Spielberg                 Horror|Thriller|Adventure
# ...

# %% [markdown]
# 首先我们需要拆分同一部电影的多个导演:
# 提示: 这个博客能够帮助你理解# 部分电影有多个导演, 用 '|' 分开
# tmp = movie_data['director'].str.split('|', expand=True).stack().reset_index(level=1, drop=True).rename('director')
# movie_data_split = movie_data[['original_title', 'revenue']].join(tmp)
# 最多产的10位导演, 解读: 名字出现最多的10名, 可以用pandas.Series.value_counts, 这里得到10个导演的名字
#
# 筛选这些导演的电影, 可以用pandas.DataFrame.isin
#
# 然后可以分别作条形图了, 这里可以结合for循环使用subplots
# 参考效果, 可见, 我们使用了subplots作为一个维度进行可视化:
#
# 其他参考:https://review.udacity.com/#!/reviews/1626134
# 拓展
# 可以在这个简单的教程了解matplotlib的作图机制 : https://www.jianshu.com/p/ec2dcd35d826
# 在合适的场景使用合适的可视化手段, 可以看这个整理
# 一个比较badass的可视化整理博客
# 又一个比较badass的可视化灵感搜集网站
# 分享一些我的探索
# 考察不同年份中, 不同电影类型的发行情况.
# # 拆分电影类型
# df_genres = df.drop('genres', axis=1).join(df['genres'].str.split('|', expand=True) \
#                                .stack().reset_index(level=1, drop=True).rename('genres'))
# fig, axes = plt.subplots(2, 1, figsize=(20, 10))
#
# # 为了易于辨认, 只展示部分电影类型
# top5_genres = df_genres['genres'].value_counts().nlargest(5).index
# btm5_genres = df_genres['genres'].value_counts().nsmallest(5).index
#
# # 作出中位数参考线
# median_cir = df_genres.groupby('release_year')['genres'].value_counts().unstack().mean(axis=1)
# median_cir.plot(ax=axes[0], ls='--', label='mean', legend=True)
# median_cir.plot(ax=axes[1], ls='--', label='mean', legend=True)
#
# # 按年份作图
# vis_params = {'grid': True, 'marker': 'o', 'markersize': 2, 'linewidth': 1}
# df_genres[df_genres['genres'].isin(top5_genres)] \
#                  .groupby('release_year')['genres'].value_counts().unstack().fillna(0) \
#                  .plot(ax=axes[0], title='circulation over years of top 5 genres', **vis_params)
# df_genres[df_genres['genres'].isin(btm5_genres)] \
#                  .groupby('release_year')['genres'].value_counts().unstack().fillna(0) \
#                  .plot(ax=axes[1], title='circulation over years of bottom 5 genres', **vis_params)
#
# plt.tight_layout()
#
# 按总收益来看, 哪些描述电影的关键字出现频率最多
# import matplotlib.pyplot as plt
# from wordcloud import WordCloud
# %config InlineBackend.figure_format = 'retina'
#
# # organize data
# factor = 'revenue_adj'
# data = pd.read_csv('tmdb-movies.csv')
# kw_expand = data['keywords'].str.split('|', expand=True).stack().reset_index(level=1, drop=True).rename('keywords')
# df_kw_rev = data[[factor]].join(kw_expand)
# word_dict = df_kw_rev.groupby('keywords')[factor].sum().to_dict()
#
# # create wordcloud
# params = {'mode': 'RGBA',
#           'background_color': 'rgba(255, 255, 255, 0)',
#           'colormap': 'Spectral'}
# wordcloud = WordCloud(width=1200, height=800, **params)
# wordcloud.generate_from_frequencies(word_dict)
#
# # plot
# plt.figure(figsize=(15, 10))
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis('off')

# %% [markdown]
# ---
#
# **[选做]任务3.4：**分析1968年~2015年六月电影的数量的变化。

# %% [markdown]
# ---
#
# **[选做]任务3.5：**分析1968年~2015年六月电影 `Comedy` 和 `Drama` 两类电影的数量的变化。

# %% [markdown]
# > 注意: 当你写完了所有的代码，并且回答了所有的问题。你就可以把你的 iPython Notebook 导出成 HTML 文件。你可以在菜单栏，这样导出**File -> Download as -> HTML (.html)、Python (.py)** 把导出的 HTML、python文件 和这个 iPython notebook 一起提交给审阅者。
